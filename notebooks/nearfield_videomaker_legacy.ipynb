# %% [markdown]
# # LOFAR single station imaging - Video making

# %%
import numpy as np
import os
import re
import getpass
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import glob
import cv2
import time
import sys
sys.path.append('..')

# %%
from lofarantpos.db import LofarAntennaDatabase
from lofarimaging import read_acm_cube, get_station_type, make_xst_plots

# %%
# %load_ext autoreload
# %autoreload 2

# %%
db = LofarAntennaDatabase()

# %%
username = getpass.getuser()
data_dir = f"/home/{username}/Documents/LV614_image_data/"
caltable_dir = f"/home/{username}/Documents/LV614_image_data/CalTables/"
caltable_dir = "CalTables/"

output_dir = "results/movie"
temp_dir = output_dir + "/temp"
fps = 10

# Observation that works
obs_dir = data_dir + "sess_sid20230111T071252_LV614/scan_59955.30061/LV614_20230111_071256_spw3_sb51_461_int1_dur24300_dir0,0,SUN_xst/"

# Observation info
station_name = "LV614"
integration_time_s = 2
rcu_mode = 3
height = 1.5
station_type = get_station_type(station_name)

# %%
def get_subbands(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
    match = re.search(r'--xcsubband=(\d+)', content)
    return int(match.group(1)) if match else None

def get_obstime(file_path):
    obsdatestr, obstimestr, *_ = os.path.basename(file_path).rstrip(".dat").split("_")
    return datetime.datetime.strptime(obsdatestr + ":" + obstimestr, '%Y%m%d:%H%M%S')

def analyze_files(data_files):
    dat_files = sorted(glob.glob(os.path.join(data_files, '*.dat')))
    h_files = sorted(glob.glob(os.path.join(data_files, '*.h')))

    assert len(dat_files) == len(h_files), "Mismatch in number of .dat and .h files"

    data_list = []

    for dat_file, h_file in zip(dat_files, h_files):
        timestamp = get_obstime(dat_file)
        timestamp2 = get_obstime(h_file)
        if timestamp != timestamp2:
            print(f"Warning: timestamps do not match for {dat_file} and {h_file}")
        subband = get_subbands(h_file)

        data_list.append({
            "timestamp": timestamp,
            "subband": subband,
            "dat_file": dat_file,
            "h_file": h_file
        })

    df = pd.DataFrame(data_list)
    df = df.sort_values(by=["timestamp", "subband"]).reset_index(drop=True)

    average_measures_per_subband = round(df["subband"].value_counts().mean(), 2)
    measurement_duration = round((df["timestamp"].max() - df["timestamp"].min()).total_seconds() / len(df), 2) if len(df) > 1 else None

    summary = {
        "number_of_files": len(df),
        "subbands_available": {
            "first_subband": df["subband"].min(),
            "last_subband": df["subband"].max(),
            "total_subbands": len(df["subband"].dropna().unique())
        },
        "start_time": df["timestamp"].min(),
        "end_time": df["timestamp"].max(),
        "average_measures_per_subband": average_measures_per_subband,
        "measurement_duration": measurement_duration
    }

    return df, summary

def print_summary(summary):
    print("Summary of Analyzed Files:")
    print(f"Number of files: {summary['number_of_files']}")
    print(f"First and last subband: {summary['subbands_available']['first_subband']} - {summary['subbands_available']['last_subband']}")
    print(f"Total subbands: {summary['subbands_available']['total_subbands']}")
    print(f"Start time: {summary['start_time']}")
    print(f"End time: {summary['end_time']}")
    print(f"Average measurements per subband: {summary['average_measures_per_subband']}")
    print(f"Average measurement duration: {summary['measurement_duration']} seconds")


def generate_movie(sources, output_path, fps=10):
    if not sources:
        print("Image list is empty.")
        return

    # Use the first image to get the size of the frame
    image = cv2.imread(sources[0])
    if image is None:
        print(f"Error reading image: {sources[0]}. Aborting.")
        return

    height, width, _ = image.shape

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Iterate through the images and write them to the movie
    for path in sources:
        image = cv2.imread(path)
        if image is None:
            print(f"Error reading image: {path}. It will be skipped.")
            continue
        out.write(image)

    out.release()
    cv2.destroyAllWindows()


def generate_movie_from_list(list_path, output_path, fps=10):
    with open(list_path, "r") as file:
        sources = file.read().splitlines()
    generate_movie(sources, output_path, fps=fps)

# %%
df, summary = analyze_files(obs_dir)
print_summary(summary)
# Out:
# Summary of Analyzed Files:
# Number of files: 12150
# First and last subband: 51 - 461
# Total subbands: 411
# Start time: 2023-01-11 07:12:56
# End time: 2023-01-11 13:57:54
# Average measurements per subband: 29.56
# Average measurement duration: 2.0 seconds
#                 timestamp  subband  \
# 0     2023-01-11 07:12:56       51
# 1     2023-01-11 07:12:58       52
# 2     2023-01-11 07:13:00       53
# 3     2023-01-11 07:13:02       54
# 4     2023-01-11 07:13:04       55
# ...                   ...      ...
# 12145 2023-01-11 13:57:46      277
# 12146 2023-01-11 13:57:48      278
# 12147 2023-01-11 13:57:50      279
# 12148 2023-01-11 13:57:52      280
# 12149 2023-01-11 13:57:54      281
#
#                                                 dat_file  \
# 0      /home/jan/Documents/LV614_image_data/sess_sid2...
# 1      /home/jan/Documents/LV614_image_data/sess_sid2...
# 2      /home/jan/Documents/LV614_image_data/sess_sid2...
# 3      /home/jan/Documents/LV614_image_data/sess_sid2...
# 4      /home/jan/Documents/LV614_image_data/sess_sid2...
# ...                                                  ...
# 12145  /home/jan/Documents/LV614_image_data/sess_sid2...
# 12146  /home/jan/Documents/LV614_image_data/sess_sid2...
# 12147  /home/jan/Documents/LV614_image_data/sess_sid2...
# 12148  /home/jan/Documents/LV614_image_data/sess_sid2...
# 12149  /home/jan/Documents/LV614_image_data/sess_sid2...
#
#                                                   h_file
# 0      /home/jan/Documents/LV614_image_data/sess_sid2...
# 1      /home/jan/Documents/LV614_image_data/sess_sid2...
# 2      /home/jan/Documents/LV614_image_data/sess_sid2...
# 3      /home/jan/Documents/LV614_image_data/sess_sid2...
# 4      /home/jan/Documents/LV614_image_data/sess_sid2...
# ...                                                  ...
# 12145  /home/jan/Documents/LV614_image_data/sess_sid2...
# 12146  /home/jan/Documents/LV614_image_data/sess_sid2...
# 12147  /home/jan/Documents/LV614_image_data/sess_sid2...
# 12148  /home/jan/Documents/LV614_image_data/sess_sid2...
# 12149  /home/jan/Documents/LV614_image_data/sess_sid2...
#
# [12150 rows x 4 columns]

# %%
# Temporal evolution of the selected subbands

height = 1.5

subbands = [200, 280, 360]
#subbands = [255]

sky_movie = []
nf_movie = []

for subband in subbands:
    subband_data = df[df['subband'] == subband]#.head(3)

    for index, row in subband_data.iterrows():
        xst_filename = row['dat_file']
        obstime = row['timestamp']
        time.sleep(0.1)

        try:
            print(f"Generating image for subband {subband} at time {obstime} and heigth {height} m.")
            visibilities = read_acm_cube(xst_filename, station_type)[0]
            sky_image_path, nf_image_path, _ = make_xst_plots(visibilities, station_name, obstime, subband, rcu_mode, map_zoom=18, outputpath=temp_dir, mark_max_power=True, height=height, return_only_paths=True)
            sky_movie.append(sky_image_path)
            nf_movie.append(nf_image_path)
        except Exception as e:
            print(f"Error generating image for {xst_filename}: {e}")

# Export the image lists for movie generation
with open(f"{temp_dir}/sky_image_list_time_sweep.txt", "w") as sky_file:
    sky_file.write("\n".join(sky_movie))

with open(f"{temp_dir}/nf_image_list_time_sweep.txt", "w") as nf_file:
    nf_file.write("\n".join(nf_movie))

print("Image generation complete for time sweep.")

generate_movie_from_list(f"{temp_dir}/sky_image_list_time_sweep.txt", f"{output_dir}/sky_movie_time_sweep.mp4", fps=fps)
generate_movie_from_list(f"{temp_dir}/nf_image_list_time_sweep.txt", f"{output_dir}/nf_movie_time_sweep.mp4", fps=fps)

print("Movie generation complete.")
# Out:
# Generating image for subband 200 at time 2023-01-11 07:17:54 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 07:31:36 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 07:45:18 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 07:59:00 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 08:26:24 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 08:40:06 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 08:53:48 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 09:07:30 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 09:21:12 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 09:34:54 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 09:48:36 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 10:02:18 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 10:16:00 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 10:29:42 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 10:57:06 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 11:10:48 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 11:24:30 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 11:38:12 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 11:51:54 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 12:05:36 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 12:19:18 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 12:33:00 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 12:46:42 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 13:00:24 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 13:14:06 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 13:27:48 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 13:41:30 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 13:55:12 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 07:20:34 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 07:34:16 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 07:47:58 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 08:01:40 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 08:29:04 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 08:42:46 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 08:56:28 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 09:10:10 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 09:23:52 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 09:37:34 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 09:51:16 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 10:04:58 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 10:18:40 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 10:32:22 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 10:59:46 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 11:13:28 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 11:27:10 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 11:40:52 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 11:54:34 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 12:08:16 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 12:21:58 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 12:35:40 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 12:49:22 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 13:03:04 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 13:16:46 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 13:30:28 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 13:44:10 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 13:57:52 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 07:23:14 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 07:36:56 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 07:50:38 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 08:18:02 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 08:31:44 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 08:45:26 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 08:59:08 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 09:12:50 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 09:26:32 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 09:40:14 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 09:53:56 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 10:07:38 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 10:21:20 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 10:48:44 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 11:02:26 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 11:16:08 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 11:29:50 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 11:43:32 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 11:57:14 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 12:10:56 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 12:24:38 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 12:38:20 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 12:52:02 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 13:05:44 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 13:19:26 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 13:33:08 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 13:46:50 and heigth 1.5 m.
# Image generation complete.
# Movie generation complete.

# %%
# Subband sweep at a given time

height = 1.5

subband_min = 180
subband_max = 460
subband_step = 2
subbands = df["subband"].unique()
subbands = [s for s in sorted(subbands) if subband_min <= s <= subband_max][::subband_step]

min_time = df["timestamp"].min()
times = [
    #min_time + datetime.timedelta(minutes=5),
    min_time + datetime.timedelta(minutes=50),
    min_time + datetime.timedelta(minutes=200)
]

sky_movie = []
nf_movie = []

for t in times:

    for subband in subbands:
        subband_data = df[df['subband'] == subband]

        subband_data = subband_data[subband_data['timestamp'] >= t]
        subband_data = subband_data.sort_values('timestamp')
        closest_row = subband_data.iloc[0] if not subband_data.empty else None

        if closest_row is None:
            print(f"No data found for subband {subband} at {t}")
            continue

        xst_filename = closest_row['dat_file']
        obstime = closest_row['timestamp']

        try:
            print(f"Generating image for subband {subband} at time {obstime} and heigth {height} m.")
            visibilities = read_acm_cube(xst_filename, station_type)[0]
            sky_image_path, nf_image_path, _ = make_xst_plots(visibilities, station_name, obstime, subband, rcu_mode, map_zoom=18, outputpath=temp_dir, mark_max_power=True, height=height, return_only_paths=True)
            sky_movie.append(sky_image_path)
            nf_movie.append(nf_image_path)
        except Exception as e:
            print(f"Error generating image for {xst_filename}: {e}")

# Export the image lists for movie generation
with open(f"{temp_dir}/sky_image_list_subband_sweep.txt", "w") as sky_file:
    sky_file.write("\n".join(sky_movie))

with open(f"{temp_dir}/nf_image_list_subband_sweep.txt", "w") as nf_file:
    nf_file.write("\n".join(nf_movie))

print("Image generation complete for subband sweep.")

generate_movie_from_list(f"{temp_dir}/sky_image_list_subband_sweep.txt", f"{output_dir}/sky_movie_subband_sweep.mp4", fps=fps)
generate_movie_from_list(f"{temp_dir}/nf_image_list_subband_sweep.txt", f"{output_dir}/nf_movie_subband_sweep.mp4", fps=fps)

print("Movie generation complete.")
# Out:
# Generating image for subband 180 at time 2023-01-11 08:12:02 and heigth 1.5 m.
# Generating image for subband 182 at time 2023-01-11 08:12:06 and heigth 1.5 m.
# Generating image for subband 184 at time 2023-01-11 08:12:10 and heigth 1.5 m.
# Generating image for subband 186 at time 2023-01-11 08:12:14 and heigth 1.5 m.
# Generating image for subband 188 at time 2023-01-11 08:12:18 and heigth 1.5 m.
# Generating image for subband 190 at time 2023-01-11 08:12:22 and heigth 1.5 m.
# Generating image for subband 192 at time 2023-01-11 08:12:26 and heigth 1.5 m.
# Generating image for subband 194 at time 2023-01-11 08:12:30 and heigth 1.5 m.
# Generating image for subband 196 at time 2023-01-11 08:12:34 and heigth 1.5 m.
# Generating image for subband 198 at time 2023-01-11 08:12:38 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 1.5 m.
# Generating image for subband 202 at time 2023-01-11 08:12:46 and heigth 1.5 m.
# Generating image for subband 204 at time 2023-01-11 08:12:50 and heigth 1.5 m.
# Generating image for subband 206 at time 2023-01-11 08:12:54 and heigth 1.5 m.
# Generating image for subband 208 at time 2023-01-11 08:12:58 and heigth 1.5 m.
# Generating image for subband 210 at time 2023-01-11 08:13:02 and heigth 1.5 m.
# Generating image for subband 212 at time 2023-01-11 08:13:06 and heigth 1.5 m.
# Generating image for subband 214 at time 2023-01-11 08:13:10 and heigth 1.5 m.
# Generating image for subband 216 at time 2023-01-11 08:13:14 and heigth 1.5 m.
# Generating image for subband 218 at time 2023-01-11 08:13:18 and heigth 1.5 m.
# Generating image for subband 220 at time 2023-01-11 08:13:22 and heigth 1.5 m.
# Generating image for subband 222 at time 2023-01-11 08:13:26 and heigth 1.5 m.
# Generating image for subband 224 at time 2023-01-11 08:13:30 and heigth 1.5 m.
# Generating image for subband 226 at time 2023-01-11 08:13:34 and heigth 1.5 m.
# Generating image for subband 228 at time 2023-01-11 08:13:38 and heigth 1.5 m.
# Generating image for subband 230 at time 2023-01-11 08:13:42 and heigth 1.5 m.
# Generating image for subband 232 at time 2023-01-11 08:13:46 and heigth 1.5 m.
# Generating image for subband 234 at time 2023-01-11 08:13:50 and heigth 1.5 m.
# Generating image for subband 236 at time 2023-01-11 08:13:54 and heigth 1.5 m.
# Generating image for subband 238 at time 2023-01-11 08:13:58 and heigth 1.5 m.
# Generating image for subband 240 at time 2023-01-11 08:14:02 and heigth 1.5 m.
# Generating image for subband 242 at time 2023-01-11 08:14:06 and heigth 1.5 m.
# Generating image for subband 244 at time 2023-01-11 08:14:10 and heigth 1.5 m.
# Generating image for subband 246 at time 2023-01-11 08:14:14 and heigth 1.5 m.
# Generating image for subband 248 at time 2023-01-11 08:14:18 and heigth 1.5 m.
# Generating image for subband 250 at time 2023-01-11 08:14:22 and heigth 1.5 m.
# Generating image for subband 252 at time 2023-01-11 08:14:26 and heigth 1.5 m.
# Generating image for subband 254 at time 2023-01-11 08:14:30 and heigth 1.5 m.
# Generating image for subband 256 at time 2023-01-11 08:14:34 and heigth 1.5 m.
# Generating image for subband 258 at time 2023-01-11 08:14:38 and heigth 1.5 m.
# Generating image for subband 260 at time 2023-01-11 08:14:42 and heigth 1.5 m.
# Generating image for subband 262 at time 2023-01-11 08:14:46 and heigth 1.5 m.
# Generating image for subband 264 at time 2023-01-11 08:14:50 and heigth 1.5 m.
# Generating image for subband 266 at time 2023-01-11 08:14:54 and heigth 1.5 m.
# Generating image for subband 268 at time 2023-01-11 08:14:58 and heigth 1.5 m.
# Generating image for subband 270 at time 2023-01-11 08:15:02 and heigth 1.5 m.
# Generating image for subband 272 at time 2023-01-11 08:15:06 and heigth 1.5 m.
# Generating image for subband 274 at time 2023-01-11 08:15:10 and heigth 1.5 m.
# Generating image for subband 276 at time 2023-01-11 08:15:14 and heigth 1.5 m.
# Generating image for subband 278 at time 2023-01-11 08:15:18 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 1.5 m.
# Generating image for subband 282 at time 2023-01-11 08:15:26 and heigth 1.5 m.
# Generating image for subband 284 at time 2023-01-11 08:15:30 and heigth 1.5 m.
# Generating image for subband 286 at time 2023-01-11 08:15:34 and heigth 1.5 m.
# Generating image for subband 288 at time 2023-01-11 08:15:38 and heigth 1.5 m.
# Generating image for subband 290 at time 2023-01-11 08:15:42 and heigth 1.5 m.
# Generating image for subband 292 at time 2023-01-11 08:15:46 and heigth 1.5 m.
# Generating image for subband 294 at time 2023-01-11 08:15:50 and heigth 1.5 m.
# Generating image for subband 296 at time 2023-01-11 08:15:54 and heigth 1.5 m.
# Generating image for subband 298 at time 2023-01-11 08:15:58 and heigth 1.5 m.
# Generating image for subband 300 at time 2023-01-11 08:16:02 and heigth 1.5 m.
# Generating image for subband 302 at time 2023-01-11 08:16:06 and heigth 1.5 m.
# Generating image for subband 304 at time 2023-01-11 08:16:10 and heigth 1.5 m.
# Generating image for subband 306 at time 2023-01-11 08:16:14 and heigth 1.5 m.
# Generating image for subband 308 at time 2023-01-11 08:16:18 and heigth 1.5 m.
# Generating image for subband 310 at time 2023-01-11 08:16:22 and heigth 1.5 m.
# Generating image for subband 312 at time 2023-01-11 08:16:26 and heigth 1.5 m.
# Generating image for subband 314 at time 2023-01-11 08:16:30 and heigth 1.5 m.
# Generating image for subband 316 at time 2023-01-11 08:16:34 and heigth 1.5 m.
# Generating image for subband 318 at time 2023-01-11 08:02:56 and heigth 1.5 m.
# Generating image for subband 320 at time 2023-01-11 08:03:00 and heigth 1.5 m.
# Generating image for subband 322 at time 2023-01-11 08:03:04 and heigth 1.5 m.
# Generating image for subband 324 at time 2023-01-11 08:03:08 and heigth 1.5 m.
# Generating image for subband 326 at time 2023-01-11 08:03:12 and heigth 1.5 m.
# Generating image for subband 328 at time 2023-01-11 08:03:16 and heigth 1.5 m.
# Generating image for subband 330 at time 2023-01-11 08:03:20 and heigth 1.5 m.
# Generating image for subband 332 at time 2023-01-11 08:03:24 and heigth 1.5 m.
# Generating image for subband 334 at time 2023-01-11 08:03:28 and heigth 1.5 m.
# Generating image for subband 336 at time 2023-01-11 08:03:32 and heigth 1.5 m.
# Generating image for subband 338 at time 2023-01-11 08:03:36 and heigth 1.5 m.
# Generating image for subband 340 at time 2023-01-11 08:03:40 and heigth 1.5 m.
# Generating image for subband 342 at time 2023-01-11 08:03:44 and heigth 1.5 m.
# Generating image for subband 344 at time 2023-01-11 08:03:48 and heigth 1.5 m.
# Generating image for subband 346 at time 2023-01-11 08:03:52 and heigth 1.5 m.
# Generating image for subband 348 at time 2023-01-11 08:03:56 and heigth 1.5 m.
# Generating image for subband 350 at time 2023-01-11 08:04:00 and heigth 1.5 m.
# Generating image for subband 352 at time 2023-01-11 08:04:04 and heigth 1.5 m.
# Generating image for subband 354 at time 2023-01-11 08:04:08 and heigth 1.5 m.
# Generating image for subband 356 at time 2023-01-11 08:04:12 and heigth 1.5 m.
# Generating image for subband 358 at time 2023-01-11 08:04:16 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 1.5 m.
# Generating image for subband 362 at time 2023-01-11 08:04:24 and heigth 1.5 m.
# Generating image for subband 364 at time 2023-01-11 08:04:28 and heigth 1.5 m.
# Generating image for subband 366 at time 2023-01-11 08:04:32 and heigth 1.5 m.
# Generating image for subband 368 at time 2023-01-11 08:04:36 and heigth 1.5 m.
# Generating image for subband 370 at time 2023-01-11 08:04:40 and heigth 1.5 m.
# Generating image for subband 372 at time 2023-01-11 08:04:44 and heigth 1.5 m.
# Generating image for subband 374 at time 2023-01-11 08:04:48 and heigth 1.5 m.
# Generating image for subband 376 at time 2023-01-11 08:04:52 and heigth 1.5 m.
# Generating image for subband 378 at time 2023-01-11 08:04:56 and heigth 1.5 m.
# Generating image for subband 380 at time 2023-01-11 08:05:00 and heigth 1.5 m.
# Generating image for subband 382 at time 2023-01-11 08:05:04 and heigth 1.5 m.
# Generating image for subband 384 at time 2023-01-11 08:05:08 and heigth 1.5 m.
# Generating image for subband 386 at time 2023-01-11 08:05:12 and heigth 1.5 m.
# Generating image for subband 388 at time 2023-01-11 08:05:16 and heigth 1.5 m.
# Generating image for subband 390 at time 2023-01-11 08:05:20 and heigth 1.5 m.
# Generating image for subband 392 at time 2023-01-11 08:05:24 and heigth 1.5 m.
# Generating image for subband 394 at time 2023-01-11 08:05:28 and heigth 1.5 m.
# Generating image for subband 396 at time 2023-01-11 08:05:32 and heigth 1.5 m.
# Generating image for subband 398 at time 2023-01-11 08:05:36 and heigth 1.5 m.
# Generating image for subband 400 at time 2023-01-11 08:05:40 and heigth 1.5 m.
# Generating image for subband 402 at time 2023-01-11 08:05:44 and heigth 1.5 m.
# Generating image for subband 404 at time 2023-01-11 08:05:48 and heigth 1.5 m.
# Generating image for subband 406 at time 2023-01-11 08:05:52 and heigth 1.5 m.
# Generating image for subband 408 at time 2023-01-11 08:05:56 and heigth 1.5 m.
# Generating image for subband 410 at time 2023-01-11 08:06:00 and heigth 1.5 m.
# Generating image for subband 412 at time 2023-01-11 08:06:04 and heigth 1.5 m.
# Generating image for subband 414 at time 2023-01-11 08:06:08 and heigth 1.5 m.
# Generating image for subband 416 at time 2023-01-11 08:06:12 and heigth 1.5 m.
# Generating image for subband 418 at time 2023-01-11 08:06:16 and heigth 1.5 m.
# Generating image for subband 420 at time 2023-01-11 08:06:20 and heigth 1.5 m.
# Generating image for subband 422 at time 2023-01-11 08:06:24 and heigth 1.5 m.
# Generating image for subband 424 at time 2023-01-11 08:06:28 and heigth 1.5 m.
# Generating image for subband 426 at time 2023-01-11 08:06:32 and heigth 1.5 m.
# Generating image for subband 428 at time 2023-01-11 08:06:36 and heigth 1.5 m.
# Generating image for subband 430 at time 2023-01-11 08:06:40 and heigth 1.5 m.
# Generating image for subband 432 at time 2023-01-11 08:06:44 and heigth 1.5 m.
# Generating image for subband 434 at time 2023-01-11 08:06:48 and heigth 1.5 m.
# Generating image for subband 436 at time 2023-01-11 08:06:52 and heigth 1.5 m.
# Generating image for subband 438 at time 2023-01-11 08:06:56 and heigth 1.5 m.
# Generating image for subband 440 at time 2023-01-11 08:07:00 and heigth 1.5 m.
# Generating image for subband 442 at time 2023-01-11 08:07:04 and heigth 1.5 m.
# Generating image for subband 444 at time 2023-01-11 08:07:08 and heigth 1.5 m.
# Generating image for subband 446 at time 2023-01-11 08:07:12 and heigth 1.5 m.
# Generating image for subband 448 at time 2023-01-11 08:07:16 and heigth 1.5 m.
# Generating image for subband 450 at time 2023-01-11 08:07:20 and heigth 1.5 m.
# Generating image for subband 452 at time 2023-01-11 08:07:24 and heigth 1.5 m.
# Generating image for subband 454 at time 2023-01-11 08:07:28 and heigth 1.5 m.
# Generating image for subband 456 at time 2023-01-11 08:07:32 and heigth 1.5 m.
# Generating image for subband 458 at time 2023-01-11 08:07:36 and heigth 1.5 m.
# Generating image for subband 460 at time 2023-01-11 08:07:40 and heigth 1.5 m.
# Generating image for subband 180 at time 2023-01-11 10:42:44 and heigth 1.5 m.
# Generating image for subband 182 at time 2023-01-11 10:42:48 and heigth 1.5 m.
# Generating image for subband 184 at time 2023-01-11 10:42:52 and heigth 1.5 m.
# Generating image for subband 186 at time 2023-01-11 10:42:56 and heigth 1.5 m.
# Generating image for subband 188 at time 2023-01-11 10:43:00 and heigth 1.5 m.
# Generating image for subband 190 at time 2023-01-11 10:43:04 and heigth 1.5 m.
# Generating image for subband 192 at time 2023-01-11 10:43:08 and heigth 1.5 m.
# Generating image for subband 194 at time 2023-01-11 10:43:12 and heigth 1.5 m.
# Generating image for subband 196 at time 2023-01-11 10:43:16 and heigth 1.5 m.
# Generating image for subband 198 at time 2023-01-11 10:43:20 and heigth 1.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 1.5 m.
# Generating image for subband 202 at time 2023-01-11 10:43:28 and heigth 1.5 m.
# Generating image for subband 204 at time 2023-01-11 10:43:32 and heigth 1.5 m.
# Generating image for subband 206 at time 2023-01-11 10:43:36 and heigth 1.5 m.
# Generating image for subband 208 at time 2023-01-11 10:43:40 and heigth 1.5 m.
# Generating image for subband 210 at time 2023-01-11 10:43:44 and heigth 1.5 m.
# Generating image for subband 212 at time 2023-01-11 10:43:48 and heigth 1.5 m.
# Generating image for subband 214 at time 2023-01-11 10:43:52 and heigth 1.5 m.
# Generating image for subband 216 at time 2023-01-11 10:43:56 and heigth 1.5 m.
# Generating image for subband 218 at time 2023-01-11 10:44:00 and heigth 1.5 m.
# Generating image for subband 220 at time 2023-01-11 10:44:04 and heigth 1.5 m.
# Generating image for subband 222 at time 2023-01-11 10:44:08 and heigth 1.5 m.
# Generating image for subband 224 at time 2023-01-11 10:44:12 and heigth 1.5 m.
# Generating image for subband 226 at time 2023-01-11 10:44:16 and heigth 1.5 m.
# Generating image for subband 228 at time 2023-01-11 10:44:20 and heigth 1.5 m.
# Generating image for subband 230 at time 2023-01-11 10:44:24 and heigth 1.5 m.
# Generating image for subband 232 at time 2023-01-11 10:44:28 and heigth 1.5 m.
# Generating image for subband 234 at time 2023-01-11 10:44:32 and heigth 1.5 m.
# Generating image for subband 236 at time 2023-01-11 10:44:36 and heigth 1.5 m.
# Generating image for subband 238 at time 2023-01-11 10:44:40 and heigth 1.5 m.
# Generating image for subband 240 at time 2023-01-11 10:44:44 and heigth 1.5 m.
# Generating image for subband 242 at time 2023-01-11 10:44:48 and heigth 1.5 m.
# Generating image for subband 244 at time 2023-01-11 10:44:52 and heigth 1.5 m.
# Generating image for subband 246 at time 2023-01-11 10:44:56 and heigth 1.5 m.
# Generating image for subband 248 at time 2023-01-11 10:45:00 and heigth 1.5 m.
# Generating image for subband 250 at time 2023-01-11 10:45:04 and heigth 1.5 m.
# Generating image for subband 252 at time 2023-01-11 10:45:08 and heigth 1.5 m.
# Generating image for subband 254 at time 2023-01-11 10:45:12 and heigth 1.5 m.
# Generating image for subband 256 at time 2023-01-11 10:45:16 and heigth 1.5 m.
# Generating image for subband 258 at time 2023-01-11 10:45:20 and heigth 1.5 m.
# Generating image for subband 260 at time 2023-01-11 10:45:24 and heigth 1.5 m.
# Generating image for subband 262 at time 2023-01-11 10:45:28 and heigth 1.5 m.
# Generating image for subband 264 at time 2023-01-11 10:45:32 and heigth 1.5 m.
# Generating image for subband 266 at time 2023-01-11 10:45:36 and heigth 1.5 m.
# Generating image for subband 268 at time 2023-01-11 10:45:40 and heigth 1.5 m.
# Generating image for subband 270 at time 2023-01-11 10:45:44 and heigth 1.5 m.
# Generating image for subband 272 at time 2023-01-11 10:45:48 and heigth 1.5 m.
# Generating image for subband 274 at time 2023-01-11 10:45:52 and heigth 1.5 m.
# Generating image for subband 276 at time 2023-01-11 10:45:56 and heigth 1.5 m.
# Generating image for subband 278 at time 2023-01-11 10:46:00 and heigth 1.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 1.5 m.
# Generating image for subband 282 at time 2023-01-11 10:46:08 and heigth 1.5 m.
# Generating image for subband 284 at time 2023-01-11 10:46:12 and heigth 1.5 m.
# Generating image for subband 286 at time 2023-01-11 10:46:16 and heigth 1.5 m.
# Generating image for subband 288 at time 2023-01-11 10:46:20 and heigth 1.5 m.
# Generating image for subband 290 at time 2023-01-11 10:46:24 and heigth 1.5 m.
# Generating image for subband 292 at time 2023-01-11 10:46:28 and heigth 1.5 m.
# Generating image for subband 294 at time 2023-01-11 10:46:32 and heigth 1.5 m.
# Generating image for subband 296 at time 2023-01-11 10:46:36 and heigth 1.5 m.
# Generating image for subband 298 at time 2023-01-11 10:32:58 and heigth 1.5 m.
# Generating image for subband 300 at time 2023-01-11 10:33:02 and heigth 1.5 m.
# Generating image for subband 302 at time 2023-01-11 10:33:06 and heigth 1.5 m.
# Generating image for subband 304 at time 2023-01-11 10:33:10 and heigth 1.5 m.
# Generating image for subband 306 at time 2023-01-11 10:33:14 and heigth 1.5 m.
# Generating image for subband 308 at time 2023-01-11 10:33:18 and heigth 1.5 m.
# Generating image for subband 310 at time 2023-01-11 10:33:22 and heigth 1.5 m.
# Generating image for subband 312 at time 2023-01-11 10:33:26 and heigth 1.5 m.
# Generating image for subband 314 at time 2023-01-11 10:33:30 and heigth 1.5 m.
# Generating image for subband 316 at time 2023-01-11 10:33:34 and heigth 1.5 m.
# Generating image for subband 318 at time 2023-01-11 10:33:38 and heigth 1.5 m.
# Generating image for subband 320 at time 2023-01-11 10:33:42 and heigth 1.5 m.
# Generating image for subband 322 at time 2023-01-11 10:33:46 and heigth 1.5 m.
# Generating image for subband 324 at time 2023-01-11 10:33:50 and heigth 1.5 m.
# Generating image for subband 326 at time 2023-01-11 10:33:54 and heigth 1.5 m.
# Generating image for subband 328 at time 2023-01-11 10:33:58 and heigth 1.5 m.
# Generating image for subband 330 at time 2023-01-11 10:34:02 and heigth 1.5 m.
# Generating image for subband 332 at time 2023-01-11 10:34:06 and heigth 1.5 m.
# Generating image for subband 334 at time 2023-01-11 10:34:10 and heigth 1.5 m.
# Generating image for subband 336 at time 2023-01-11 10:34:14 and heigth 1.5 m.
# Generating image for subband 338 at time 2023-01-11 10:34:18 and heigth 1.5 m.
# Generating image for subband 340 at time 2023-01-11 10:34:22 and heigth 1.5 m.
# Generating image for subband 342 at time 2023-01-11 10:34:26 and heigth 1.5 m.
# Generating image for subband 344 at time 2023-01-11 10:34:30 and heigth 1.5 m.
# Generating image for subband 346 at time 2023-01-11 10:34:34 and heigth 1.5 m.
# Generating image for subband 348 at time 2023-01-11 10:34:38 and heigth 1.5 m.
# Generating image for subband 350 at time 2023-01-11 10:34:42 and heigth 1.5 m.
# Generating image for subband 352 at time 2023-01-11 10:34:46 and heigth 1.5 m.
# Generating image for subband 354 at time 2023-01-11 10:34:50 and heigth 1.5 m.
# Generating image for subband 356 at time 2023-01-11 10:34:54 and heigth 1.5 m.
# Generating image for subband 358 at time 2023-01-11 10:34:58 and heigth 1.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 1.5 m.
# Generating image for subband 362 at time 2023-01-11 10:35:06 and heigth 1.5 m.
# Generating image for subband 364 at time 2023-01-11 10:35:10 and heigth 1.5 m.
# Generating image for subband 366 at time 2023-01-11 10:35:14 and heigth 1.5 m.
# Generating image for subband 368 at time 2023-01-11 10:35:18 and heigth 1.5 m.
# Generating image for subband 370 at time 2023-01-11 10:35:22 and heigth 1.5 m.
# Generating image for subband 372 at time 2023-01-11 10:35:26 and heigth 1.5 m.
# Generating image for subband 374 at time 2023-01-11 10:35:30 and heigth 1.5 m.
# Generating image for subband 376 at time 2023-01-11 10:35:34 and heigth 1.5 m.
# Generating image for subband 378 at time 2023-01-11 10:35:38 and heigth 1.5 m.
# Generating image for subband 380 at time 2023-01-11 10:35:42 and heigth 1.5 m.
# Generating image for subband 382 at time 2023-01-11 10:35:46 and heigth 1.5 m.
# Generating image for subband 384 at time 2023-01-11 10:35:50 and heigth 1.5 m.
# Generating image for subband 386 at time 2023-01-11 10:35:54 and heigth 1.5 m.
# Generating image for subband 388 at time 2023-01-11 10:35:58 and heigth 1.5 m.
# Generating image for subband 390 at time 2023-01-11 10:36:02 and heigth 1.5 m.
# Generating image for subband 392 at time 2023-01-11 10:36:06 and heigth 1.5 m.
# Generating image for subband 394 at time 2023-01-11 10:36:10 and heigth 1.5 m.
# Generating image for subband 396 at time 2023-01-11 10:36:14 and heigth 1.5 m.
# Generating image for subband 398 at time 2023-01-11 10:36:18 and heigth 1.5 m.
# Generating image for subband 400 at time 2023-01-11 10:36:22 and heigth 1.5 m.
# Generating image for subband 402 at time 2023-01-11 10:36:26 and heigth 1.5 m.
# Generating image for subband 404 at time 2023-01-11 10:36:30 and heigth 1.5 m.
# Generating image for subband 406 at time 2023-01-11 10:36:34 and heigth 1.5 m.
# Generating image for subband 408 at time 2023-01-11 10:36:38 and heigth 1.5 m.
# Generating image for subband 410 at time 2023-01-11 10:36:42 and heigth 1.5 m.
# Generating image for subband 412 at time 2023-01-11 10:36:46 and heigth 1.5 m.
# Generating image for subband 414 at time 2023-01-11 10:36:50 and heigth 1.5 m.
# Generating image for subband 416 at time 2023-01-11 10:36:54 and heigth 1.5 m.
# Generating image for subband 418 at time 2023-01-11 10:36:58 and heigth 1.5 m.
# Generating image for subband 420 at time 2023-01-11 10:37:02 and heigth 1.5 m.
# Generating image for subband 422 at time 2023-01-11 10:37:06 and heigth 1.5 m.
# Generating image for subband 424 at time 2023-01-11 10:37:10 and heigth 1.5 m.
# Generating image for subband 426 at time 2023-01-11 10:37:14 and heigth 1.5 m.
# Generating image for subband 428 at time 2023-01-11 10:37:18 and heigth 1.5 m.
# Generating image for subband 430 at time 2023-01-11 10:37:22 and heigth 1.5 m.
# Generating image for subband 432 at time 2023-01-11 10:37:26 and heigth 1.5 m.
# Generating image for subband 434 at time 2023-01-11 10:37:30 and heigth 1.5 m.
# Generating image for subband 436 at time 2023-01-11 10:37:34 and heigth 1.5 m.
# Generating image for subband 438 at time 2023-01-11 10:37:38 and heigth 1.5 m.
# Generating image for subband 440 at time 2023-01-11 10:37:42 and heigth 1.5 m.
# Generating image for subband 442 at time 2023-01-11 10:37:46 and heigth 1.5 m.
# Generating image for subband 444 at time 2023-01-11 10:37:50 and heigth 1.5 m.
# Generating image for subband 446 at time 2023-01-11 10:37:54 and heigth 1.5 m.
# Generating image for subband 448 at time 2023-01-11 10:37:58 and heigth 1.5 m.
# Generating image for subband 450 at time 2023-01-11 10:38:02 and heigth 1.5 m.
# Generating image for subband 452 at time 2023-01-11 10:38:06 and heigth 1.5 m.
# Generating image for subband 454 at time 2023-01-11 10:38:10 and heigth 1.5 m.
# Generating image for subband 456 at time 2023-01-11 10:38:14 and heigth 1.5 m.
# Generating image for subband 458 at time 2023-01-11 10:38:18 and heigth 1.5 m.
# Generating image for subband 460 at time 2023-01-11 10:38:22 and heigth 1.5 m.
# Image generation complete.
# Movie generation complete.

# %%
# Height sweep at a given time and subband

height_min = 1
height_max = 151
height_step = 2.5

subbands = [200, 280, 360]
#subbands = [255]

min_time = df["timestamp"].min()
times = [
    #min_time + datetime.timedelta(minutes=5),
    min_time + datetime.timedelta(minutes=50),
    min_time + datetime.timedelta(minutes=200)
]

sky_movie = []
nf_movie = []

for t in times:
    for subband in subbands:
        subband_data = df[df['subband'] == subband]

        subband_data = subband_data[subband_data['timestamp'] >= t]
        subband_data = subband_data.sort_values('timestamp')
        closest_row = subband_data.iloc[0] if not subband_data.empty else None

        if closest_row is None:
            print(f"No data found for subband {subband} at {t}")
            continue

        for height in np.arange(height_min, height_max, height_step):
            xst_filename = closest_row['dat_file']
            obstime = closest_row['timestamp']

            try:
                print(f"Generating image for subband {subband} at time {obstime} and heigth {height} m.")
                visibilities = read_acm_cube(xst_filename, station_type)[0]
                sky_image_path, nf_image_path, _ = make_xst_plots(visibilities, station_name, obstime, subband, rcu_mode, map_zoom=18, outputpath=temp_dir, mark_max_power=True, height=height, return_only_paths=True)
                sky_movie.append(sky_image_path)
                nf_movie.append(nf_image_path)
            except Exception as e:
                print(f"Error generating image for {xst_filename}: {e}")

with open(f"{temp_dir}/nf_image_list_heigth_sweep.txt", "w") as nf_file:
    nf_file.write("\n".join(nf_movie))

print("Image generation complete for height sweep.")

generate_movie_from_list(f"{temp_dir}/nf_image_list_heigth_sweep.txt", f"{output_dir}/nf_movie_heigth_sweep.mp4", fps=fps)

print("Movie generation complete.")
# Out:
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 1.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 3.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 6.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 8.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 11.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 13.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 16.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 18.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 21.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 23.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 26.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 28.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 31.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 33.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 36.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 38.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 41.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 43.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 46.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 48.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 51.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 53.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 56.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 58.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 61.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 63.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 66.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 68.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 71.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 73.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 76.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 78.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 81.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 83.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 86.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 88.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 91.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 93.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 96.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 98.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 101.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 103.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 106.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 108.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 111.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 113.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 116.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 118.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 121.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 123.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 126.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 128.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 131.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 133.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 136.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 138.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 141.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 143.5 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 146.0 m.
# Generating image for subband 200 at time 2023-01-11 08:12:42 and heigth 148.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 1.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 3.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 6.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 8.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 11.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 13.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 16.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 18.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 21.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 23.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 26.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 28.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 31.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 33.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 36.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 38.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 41.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 43.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 46.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 48.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 51.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 53.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 56.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 58.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 61.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 63.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 66.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 68.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 71.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 73.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 76.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 78.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 81.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 83.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 86.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 88.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 91.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 93.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 96.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 98.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 101.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 103.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 106.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 108.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 111.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 113.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 116.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 118.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 121.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 123.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 126.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 128.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 131.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 133.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 136.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 138.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 141.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 143.5 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 146.0 m.
# Generating image for subband 280 at time 2023-01-11 08:15:22 and heigth 148.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 1.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 3.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 6.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 8.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 11.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 13.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 16.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 18.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 21.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 23.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 26.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 28.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 31.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 33.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 36.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 38.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 41.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 43.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 46.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 48.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 51.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 53.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 56.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 58.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 61.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 63.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 66.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 68.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 71.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 73.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 76.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 78.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 81.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 83.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 86.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 88.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 91.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 93.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 96.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 98.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 101.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 103.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 106.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 108.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 111.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 113.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 116.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 118.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 121.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 123.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 126.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 128.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 131.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 133.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 136.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 138.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 141.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 143.5 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 146.0 m.
# Generating image for subband 360 at time 2023-01-11 08:04:20 and heigth 148.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 1.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 3.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 6.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 8.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 11.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 13.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 16.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 18.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 21.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 23.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 26.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 28.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 31.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 33.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 36.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 38.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 41.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 43.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 46.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 48.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 51.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 53.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 56.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 58.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 61.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 63.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 66.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 68.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 71.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 73.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 76.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 78.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 81.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 83.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 86.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 88.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 91.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 93.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 96.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 98.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 101.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 103.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 106.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 108.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 111.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 113.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 116.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 118.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 121.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 123.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 126.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 128.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 131.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 133.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 136.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 138.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 141.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 143.5 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 146.0 m.
# Generating image for subband 200 at time 2023-01-11 10:43:24 and heigth 148.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 1.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 3.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 6.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 8.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 11.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 13.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 16.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 18.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 21.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 23.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 26.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 28.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 31.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 33.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 36.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 38.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 41.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 43.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 46.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 48.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 51.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 53.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 56.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 58.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 61.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 63.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 66.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 68.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 71.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 73.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 76.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 78.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 81.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 83.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 86.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 88.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 91.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 93.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 96.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 98.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 101.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 103.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 106.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 108.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 111.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 113.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 116.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 118.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 121.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 123.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 126.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 128.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 131.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 133.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 136.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 138.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 141.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 143.5 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 146.0 m.
# Generating image for subband 280 at time 2023-01-11 10:46:04 and heigth 148.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 1.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 3.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 6.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 8.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 11.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 13.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 16.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 18.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 21.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 23.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 26.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 28.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 31.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 33.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 36.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 38.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 41.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 43.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 46.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 48.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 51.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 53.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 56.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 58.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 61.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 63.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 66.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 68.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 71.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 73.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 76.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 78.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 81.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 83.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 86.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 88.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 91.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 93.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 96.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 98.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 101.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 103.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 106.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 108.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 111.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 113.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 116.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 118.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 121.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 123.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 126.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 128.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 131.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 133.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 136.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 138.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 141.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 143.5 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 146.0 m.
# Generating image for subband 360 at time 2023-01-11 10:35:02 and heigth 148.5 m.
# Image generation complete.
# Movie generation complete.

# %%
generate_movie_from_list(f"{temp_dir}/sky_image_list_time_sweep.txt", f"{output_dir}/sky_movie_time_sweep.mp4", fps=fps)
generate_movie_from_list(f"{temp_dir}/nf_image_list_time_sweep.txt", f"{output_dir}/nf_movie_time_sweep.mp4", fps=fps)

generate_movie_from_list(f"{temp_dir}/sky_image_list_subband_sweep.txt", f"{output_dir}/sky_movie_subband_sweep.mp4", fps=fps)
generate_movie_from_list(f"{temp_dir}/nf_image_list_subband_sweep.txt", f"{output_dir}/nf_movie_subband_sweep.mp4", fps=fps)

generate_movie_from_list(f"{temp_dir}/nf_image_list_heigth_sweep.txt", f"{output_dir}/nf_movie_heigth_sweep.mp4", fps=fps)

print("Movie generation complete.")
# Out:
# Movie generation complete.
